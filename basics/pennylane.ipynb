# %%
import matplotlib.pyplot as plt
import pennylane as qml
from pennylane import numpy as np

# %%
dev = qml.device('default.qubit', wires=2)

@qml.qnode(dev)
def circuit(theta):
    qml.PauliX(wires=1)
    qml.CNOT(wires=[1,0])
    qml.RY(theta, wires=0)

    return qml.expval(qml.PauliZ(wires=0))

# %%
print(qml.draw(circuit)(0))
# Out:
# 0: ────╭X──RY(0.00)─┤  <Z>
# 1: ──X─╰●───────────┤

# %%
fig, ax = qml.draw_mpl(circuit)(0.25)
fig.show()
# Out:
# /tmp/ipykernel_19320/264107437.py:2: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
thetas = np.arange(-np.pi, np.pi, 0.01)

measurements = [circuit(theta) for theta in thetas]

plt.plot(thetas, measurements)
plt.show()
